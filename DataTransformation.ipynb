# %%
import pandas as pd
from pandas.api.types import is_numeric_dtype
print("pandas: %s" % pd.__version__)

import sklearn
from sklearn.preprocessing import StandardScaler
print("sklearn: %s" % sklearn.__version__)
# Out:
# pandas: 1.0.3
# sklearn: 0.23.2

# %%
# Display all the columns for the dataframes (not-truncated)
pd.set_option("display.max_columns", None)

# %%
# Read `crypto_data.csv` into Pandas. 
df = pd.read_csv("Resources/crypto_raw_data.csv")

print(df.describe())
df
# Out:
#        TotalCoinsMined  TotalCoinSupply
# count     2.596000e+03     2.597000e+03
# mean      4.168845e+19     1.041975e+11
# std       1.857952e+21     3.696239e+12
# min      -3.768142e+14    -1.000000e+00
# 25%       2.276872e+01    -1.000000e+00
# 50%       9.874886e+07    -1.000000e+00
# 75%       1.000000e+09     0.000000e+00
# max       9.354691e+22     1.829060e+14
#                 CoinName     Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0                42 Coin        Scrypt       True   PoW/PoS     0.000000e+00
# 1              300 token           NaN       True       NaN     3.000000e+02
# 2                365Coin           X11       True   PoW/PoS     0.000000e+00
# 3                404Coin        Scrypt       True   PoW/PoS     0.000000e+00
# 4              433 Token           NaN      False       NaN              NaN
# ...                  ...           ...        ...       ...              ...
# 7007            Metahero  BEP-20 Token       True       NaN     9.814709e+09
# 7008     Harvest Finance           NaN       True       NaN     6.359341e+05
# 7009                 Dai           NaN       True       NaN     6.212777e+09
# 7010             Solarex           NaN      False       NaN              NaN
# 7011  Seigniorage Shares           NaN       True       NaN     2.100000e+07
#
#       TotalCoinSupply
# 0                 0.0
# 1               300.0
# 2                 0.0
# 3                 0.0
# 4                 NaN
# ...               ...
# 7007             -1.0
# 7008         690420.0
# 7009             -1.0
# 7010              NaN
# 7011             -1.0
#
# [7012 rows x 6 columns]

# %%
def normalize_decimal_separator(line):
    """
    clean the string number from containing spaces 
    and underscores as the thousands seperator and
    also remove any commas or periods as the 
    thousands seperator
    
    returns a string
    """
    try:
        float(line)
        return line
    except ValueError: 
        # remove the spaces as the thousands seperator
        if (" " in line):
            line = line.replace(" ", "")
        # remove the underscore as the thousands seperator
        if ("_" in line):
            line = line.replace("_", "")
        # remove periods if they are the thousands seperator
        if (line.count(".") > 1):
            line = line.replace(".", "")
        # remove commas if they are the thousands seperator
        if (line.count(",") > 1):
            line = line.replace(",", "")
        #
        return line

# %%
# Fix the error in the total coin supply where the values are coming in as a string
if not is_numeric_dtype(df["TotalCoinSupply"]):
    df["TotalCoinSupply"] = pd.to_numeric(df["TotalCoinSupply"].apply(normalize_decimal_separator))
    print(df["TotalCoinSupply"].describe())
df
# Out:
#                 CoinName     Algorithm  IsTrading ProofType  TotalCoinsMined  \
# 0                42 Coin        Scrypt       True   PoW/PoS     0.000000e+00
# 1              300 token           NaN       True       NaN     3.000000e+02
# 2                365Coin           X11       True   PoW/PoS     0.000000e+00
# 3                404Coin        Scrypt       True   PoW/PoS     0.000000e+00
# 4              433 Token           NaN      False       NaN              NaN
# ...                  ...           ...        ...       ...              ...
# 7007            Metahero  BEP-20 Token       True       NaN     9.814709e+09
# 7008     Harvest Finance           NaN       True       NaN     6.359341e+05
# 7009                 Dai           NaN       True       NaN     6.212777e+09
# 7010             Solarex           NaN      False       NaN              NaN
# 7011  Seigniorage Shares           NaN       True       NaN     2.100000e+07
#
#       TotalCoinSupply
# 0                 0.0
# 1               300.0
# 2                 0.0
# 3                 0.0
# 4                 NaN
# ...               ...
# 7007             -1.0
# 7008         690420.0
# 7009             -1.0
# 7010              NaN
# 7011             -1.0
#
# [7012 rows x 6 columns]

# %%
# Discard all cryptocurrencies that are not being traded
df = df[df["IsTrading"] == True]
df["IsTrading"].value_counts()
# Out:
# True    5595
# Name: IsTrading, dtype: int64

# %%
# Drop the `IsTrading` column from the dataframe
df = df.drop(columns=["IsTrading"])
df
# Out:
#                 CoinName     Algorithm ProofType  TotalCoinsMined  \
# 0                42 Coin        Scrypt   PoW/PoS     0.000000e+00
# 1              300 token           NaN       NaN     3.000000e+02
# 2                365Coin           X11   PoW/PoS     0.000000e+00
# 3                404Coin        Scrypt   PoW/PoS     0.000000e+00
# 5              SixEleven       SHA-256       PoW     0.000000e+00
# ...                  ...           ...       ...              ...
# 7006               VidyX           NaN       NaN     1.000000e+09
# 7007            Metahero  BEP-20 Token       NaN     9.814709e+09
# 7008     Harvest Finance           NaN       NaN     6.359341e+05
# 7009                 Dai           NaN       NaN     6.212777e+09
# 7011  Seigniorage Shares           NaN       NaN     2.100000e+07
#
#       TotalCoinSupply
# 0                 0.0
# 1               300.0
# 2                 0.0
# 3                 0.0
# 5                 0.0
# ...               ...
# 7006             -1.0
# 7007             -1.0
# 7008         690420.0
# 7009             -1.0
# 7011             -1.0
#
# [5595 rows x 5 columns]

# %%
# Remove all rows that have at least one null value
print(df.isnull().sum())
df = df.dropna()
df
# Out:
# CoinName              0
# Algorithm          4047
# ProofType          3962
# TotalCoinsMined    3251
# TotalCoinSupply    3250
# dtype: int64
#              CoinName      Algorithm ProofType  TotalCoinsMined  \
# 0             42 Coin         Scrypt   PoW/PoS     0.000000e+00
# 2             365Coin            X11   PoW/PoS     0.000000e+00
# 3             404Coin         Scrypt   PoW/PoS     0.000000e+00
# 5           SixEleven        SHA-256       PoW     0.000000e+00
# 6                 808        SHA-256   PoW/PoS     0.000000e+00
# ...               ...            ...       ...              ...
# 6970             Aion  Equihash210,9   PoW/PoS     4.955230e+08
# 6972           Achain           DPoS      DPoS     1.000000e+09
# 6979             Firo            MTP       PoW     1.227754e+07
# 6984     Bitcoin Gold       Equihash       PoW     1.882890e+07
# 6987  Bitcoin Diamond            X13   PoW/PoS     2.011865e+08
#
#       TotalCoinSupply
# 0                 0.0
# 2                 0.0
# 3                 0.0
# 5                 0.0
# 6                 0.0
# ...               ...
# 6970             -1.0
# 6972              0.0
# 6979       21400000.0
# 6984       21000000.0
# 6987      210000000.0
#
# [246 rows x 5 columns]

# %%
# Filter for cryptocurrencies that have been mined
df = df[df["TotalCoinsMined"] > 0]
df
# Out:
#               CoinName      Algorithm ProofType  TotalCoinsMined  \
# 133           NovaCoin         Scrypt   PoW/PoS     3.387946e+06
# 197           NuShares            PoS       PoS     6.164782e+09
# 198           MonaCoin         Scrypt       PoW     8.299455e+07
# 231     Triangles Coin            X13   PoW/PoS     1.859555e+05
# 448   SafeExchangeCoin         Scrypt       PoC     2.147484e+09
# ...                ...            ...       ...              ...
# 6970              Aion  Equihash210,9   PoW/PoS     4.955230e+08
# 6972            Achain           DPoS      DPoS     1.000000e+09
# 6979              Firo            MTP       PoW     1.227754e+07
# 6984      Bitcoin Gold       Equihash       PoW     1.882890e+07
# 6987   Bitcoin Diamond            X13   PoW/PoS     2.011865e+08
#
#       TotalCoinSupply
# 133              -1.0
# 197               0.0
# 198              -1.0
# 231               0.0
# 448              -1.0
# ...               ...
# 6970             -1.0
# 6972              0.0
# 6979       21400000.0
# 6984       21000000.0
# 6987      210000000.0
#
# [123 rows x 5 columns]

# %%
# delete the `Unnamed: 0` and `CoinName` from the original dataframe
if ("Unnamed: 0" in df.columns):
    df = df.drop(columns=["Unnamed: 0","CoinName"])
else:
    df = df.drop(columns=["CoinName"])
df
# Out:
#           Algorithm ProofType  TotalCoinsMined  TotalCoinSupply
# 133          Scrypt   PoW/PoS     3.387946e+06             -1.0
# 197             PoS       PoS     6.164782e+09              0.0
# 198          Scrypt       PoW     8.299455e+07             -1.0
# 231             X13   PoW/PoS     1.859555e+05              0.0
# 448          Scrypt       PoC     2.147484e+09             -1.0
# ...             ...       ...              ...              ...
# 6970  Equihash210,9   PoW/PoS     4.955230e+08             -1.0
# 6972           DPoS      DPoS     1.000000e+09              0.0
# 6979            MTP       PoW     1.227754e+07       21400000.0
# 6984       Equihash       PoW     1.882890e+07       21000000.0
# 6987            X13   PoW/PoS     2.011865e+08      210000000.0
#
# [123 rows x 4 columns]

# %%
df.describe()
# Out:
#        TotalCoinsMined  TotalCoinSupply
# count     1.230000e+02     1.230000e+02
# mean      2.207488e+10     1.222058e+10
# std       1.276865e+11     9.196964e+10
# min       1.994458e+03    -1.000000e+00
# 25%       2.794300e+07    -1.000000e+00
# 50%       1.282624e+08     2.000000e+07
# 75%       1.000000e+09     1.466241e+08
# max       1.000017e+12     1.000017e+12

# %%
df.to_csv("Resources/crypto_clean_data.csv", index=False)
