# %%
import pandas as pd
from pandas.api.types import is_numeric_dtype
print("pandas: %s" % pd.__version__)

import sklearn
from sklearn.preprocessing import StandardScaler
print("sklearn: %s" % sklearn.__version__)
# Out:
# pandas: 1.0.3
# sklearn: 0.23.2

# %%
# Display all the columns for the dataframes (not-truncated)
pd.set_option("display.max_columns", None)

# %%
# Read `crypto_data.csv` into Pandas. 
df = pd.read_csv("Resources/crypto_raw_data.csv")

print(df.describe())
df
# Out:
#        TotalCoinsMined  TotalCoinSupply
# count     2.579000e+03     2.580000e+03
# mean      4.196324e+19     1.048836e+11
# std       1.864065e+21     3.708391e+12
# min      -3.768142e+14    -1.000000e+00
# 25%       3.960000e-03    -1.000000e+00
# 50%       9.850000e+07    -1.000000e+00
# 75%       1.000000e+09     0.000000e+00
# max       9.354691e+22     1.829060e+14
#                     CoinName      Algorithm  IsTrading  \
# 0                    42 Coin         Scrypt       True
# 1                  300 token            NaN       True
# 2                    365Coin            X11       True
# 3                    404Coin         Scrypt       True
# 4                  433 Token            NaN      False
# ...                      ...            ...        ...
# 6990                    Aion  Equihash210,9       True
# 6991               Aeternity            NaN       True
# 6992                  Achain           DPoS       True
# 6993               Bitcicoin            NaN       True
# 6994  Uniswap Protocol Token            NaN       True
#
#                      ProofType  TotalCoinsMined  TotalCoinSupply
# 0                      PoW/PoS     0.000000e+00              0.0
# 1                          NaN     3.000000e+02            300.0
# 2                      PoW/PoS     0.000000e+00              0.0
# 3                      PoW/PoS     0.000000e+00              0.0
# 4                          NaN              NaN              NaN
# ...                        ...              ...              ...
# 6990                   PoW/PoS     4.953610e+08             -1.0
# 6991                   PoW/PoS     3.887295e+08             -1.0
# 6992                      DPoS     1.000000e+09              0.0
# 6993  Proof-of-Authority (PoA)     1.000000e+11             -1.0
# 6994                       NaN     1.000000e+09             -1.0
#
# [6995 rows x 6 columns]

# %%
def normalize_decimal_separator(line):
    """
    clean the string number from containing spaces 
    and underscores as the thousands seperator and
    also remove any commas or periods as the 
    thousands seperator
    
    returns a string
    """
    try:
        float(line)
        return line
    except ValueError: 
        # remove the spaces as the thousands seperator
        if (" " in line):
            line = line.replace(" ", "")
        # remove the underscore as the thousands seperator
        if ("_" in line):
            line = line.replace("_", "")
        # remove periods if they are the thousands seperator
        if (line.count(".") > 1):
            line = line.replace(".", "")
        # remove commas if they are the thousands seperator
        if (line.count(",") > 1):
            line = line.replace(",", "")
        #
        return line

# %%
# Fix the error in the total coin supply where the values are coming in as a string
if not is_numeric_dtype(df["TotalCoinSupply"]):
    df["TotalCoinSupply"] = pd.to_numeric(df["TotalCoinSupply"].apply(normalize_decimal_separator))
    print(df["TotalCoinSupply"].describe())
df
# Out:
#                     CoinName      Algorithm  IsTrading  \
# 0                    42 Coin         Scrypt       True
# 1                  300 token            NaN       True
# 2                    365Coin            X11       True
# 3                    404Coin         Scrypt       True
# 4                  433 Token            NaN      False
# ...                      ...            ...        ...
# 6990                    Aion  Equihash210,9       True
# 6991               Aeternity            NaN       True
# 6992                  Achain           DPoS       True
# 6993               Bitcicoin            NaN       True
# 6994  Uniswap Protocol Token            NaN       True
#
#                      ProofType  TotalCoinsMined  TotalCoinSupply
# 0                      PoW/PoS     0.000000e+00              0.0
# 1                          NaN     3.000000e+02            300.0
# 2                      PoW/PoS     0.000000e+00              0.0
# 3                      PoW/PoS     0.000000e+00              0.0
# 4                          NaN              NaN              NaN
# ...                        ...              ...              ...
# 6990                   PoW/PoS     4.953610e+08             -1.0
# 6991                   PoW/PoS     3.887295e+08             -1.0
# 6992                      DPoS     1.000000e+09              0.0
# 6993  Proof-of-Authority (PoA)     1.000000e+11             -1.0
# 6994                       NaN     1.000000e+09             -1.0
#
# [6995 rows x 6 columns]

# %%
# Discard all cryptocurrencies that are not being traded
df = df[df["IsTrading"] == True]
df["IsTrading"].value_counts()
# Out:
# True    5582
# Name: IsTrading, dtype: int64

# %%
# Drop the `IsTrading` column from the dataframe
df = df.drop(columns=["IsTrading"])
df
# Out:
#                     CoinName      Algorithm                 ProofType  \
# 0                    42 Coin         Scrypt                   PoW/PoS
# 1                  300 token            NaN                       NaN
# 2                    365Coin            X11                   PoW/PoS
# 3                    404Coin         Scrypt                   PoW/PoS
# 5                  SixEleven        SHA-256                       PoW
# ...                      ...            ...                       ...
# 6990                    Aion  Equihash210,9                   PoW/PoS
# 6991               Aeternity            NaN                   PoW/PoS
# 6992                  Achain           DPoS                      DPoS
# 6993               Bitcicoin            NaN  Proof-of-Authority (PoA)
# 6994  Uniswap Protocol Token            NaN                       NaN
#
#       TotalCoinsMined  TotalCoinSupply
# 0        0.000000e+00              0.0
# 1        3.000000e+02            300.0
# 2        0.000000e+00              0.0
# 3        0.000000e+00              0.0
# 5        0.000000e+00              0.0
# ...               ...              ...
# 6990     4.953610e+08             -1.0
# 6991     3.887295e+08             -1.0
# 6992     1.000000e+09              0.0
# 6993     1.000000e+11             -1.0
# 6994     1.000000e+09             -1.0
#
# [5582 rows x 5 columns]

# %%
# Remove all rows that have at least one null value
print(df.isnull().sum())
df = df.dropna()
df
# Out:
# CoinName              0
# Algorithm          4037
# ProofType          3949
# TotalCoinsMined    3251
# TotalCoinSupply    3250
# dtype: int64
#           CoinName      Algorithm ProofType  TotalCoinsMined  TotalCoinSupply
# 0          42 Coin         Scrypt   PoW/PoS     0.000000e+00     0.000000e+00
# 2          365Coin            X11   PoW/PoS     0.000000e+00     0.000000e+00
# 3          404Coin         Scrypt   PoW/PoS     0.000000e+00     0.000000e+00
# 5        SixEleven        SHA-256       PoW     0.000000e+00     0.000000e+00
# 6              808        SHA-256   PoW/PoS     0.000000e+00     0.000000e+00
# ...            ...            ...       ...              ...              ...
# 6984       Bitcoin        SHA-256       PoW     1.880552e+07     2.100000e+07
# 6985  Binance Coin          BEP-2      PoSA     1.681370e+08    -1.000000e+00
# 6987           ARK           DPoS      DPoS     1.596877e+08    -1.000000e+00
# 6990          Aion  Equihash210,9   PoW/PoS     4.953610e+08    -1.000000e+00
# 6992        Achain           DPoS      DPoS     1.000000e+09     0.000000e+00
#
# [246 rows x 5 columns]

# %%
# Filter for cryptocurrencies that have been mined
df = df[df["TotalCoinsMined"] > 0]
df
# Out:
#               CoinName      Algorithm ProofType  TotalCoinsMined  \
# 133           NovaCoin         Scrypt   PoW/PoS     3.383067e+06
# 197           NuShares            PoS       PoS     6.164543e+09
# 198           MonaCoin         Scrypt       PoW     8.294686e+07
# 231     Triangles Coin            X13   PoW/PoS     1.857394e+05
# 448   SafeExchangeCoin         Scrypt       PoC     2.147484e+09
# ...                ...            ...       ...              ...
# 6984           Bitcoin        SHA-256       PoW     1.880552e+07
# 6985      Binance Coin          BEP-2      PoSA     1.681370e+08
# 6987               ARK           DPoS      DPoS     1.596877e+08
# 6990              Aion  Equihash210,9   PoW/PoS     4.953610e+08
# 6992            Achain           DPoS      DPoS     1.000000e+09
#
#       TotalCoinSupply
# 133     -1.000000e+00
# 197      0.000000e+00
# 198     -1.000000e+00
# 231      0.000000e+00
# 448     -1.000000e+00
# ...               ...
# 6984     2.100000e+07
# 6985    -1.000000e+00
# 6987    -1.000000e+00
# 6990    -1.000000e+00
# 6992     0.000000e+00
#
# [123 rows x 5 columns]

# %%
# delete the `Unnamed: 0` and `CoinName` from the original dataframe
if ("Unnamed: 0" in df.columns):
    df = df.drop(columns=["Unnamed: 0","CoinName"])
else:
    df = df.drop(columns=["CoinName"])
df
# Out:
#           Algorithm ProofType  TotalCoinsMined  TotalCoinSupply
# 133          Scrypt   PoW/PoS     3.383067e+06    -1.000000e+00
# 197             PoS       PoS     6.164543e+09     0.000000e+00
# 198          Scrypt       PoW     8.294686e+07    -1.000000e+00
# 231             X13   PoW/PoS     1.857394e+05     0.000000e+00
# 448          Scrypt       PoC     2.147484e+09    -1.000000e+00
# ...             ...       ...              ...              ...
# 6984        SHA-256       PoW     1.880552e+07     2.100000e+07
# 6985          BEP-2      PoSA     1.681370e+08    -1.000000e+00
# 6987           DPoS      DPoS     1.596877e+08    -1.000000e+00
# 6990  Equihash210,9   PoW/PoS     4.953610e+08    -1.000000e+00
# 6992           DPoS      DPoS     1.000000e+09     0.000000e+00
#
# [123 rows x 4 columns]

# %%
df.describe()
# Out:
#        TotalCoinsMined  TotalCoinSupply
# count     1.230000e+02     1.230000e+02
# mean      2.207234e+10     1.222058e+10
# std       1.276859e+11     9.196964e+10
# min       1.982992e+03    -1.000000e+00
# 25%       2.794300e+07    -1.000000e+00
# 50%       1.281759e+08     2.000000e+07
# 75%       1.000000e+09     1.466241e+08
# max       1.000017e+12     1.000017e+12

# %%
df.to_csv("Resources/crypto_clean_data.csv", index=False)
